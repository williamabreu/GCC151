# %%
import os
os.chdir('..')

# %%
from nlputils.crawler import crawler

# %% [markdown]
# ### Telefonia

# %% [markdown]
# Baixar no máximo 600 arquivos, se possível.

# %%
crawler.Crawler(
    'data/corpora/telefonia', 
    600, 
    'https://www.tudocelular.com/mercado/noticias/n140890/crescimento-5g-brasil-depende-regulacao-normas.html', 
    '"(https://www\.tudocelular\.com/mercado/.*?)"'
).crawl()
# Out:
# getting page https://www.tudocelular.com/mercado/noticias/n140890/crescimento-5g-brasil-depende-regulacao-normas.html
# getting page https://www.tudocelular.com/mercado/noticias/n140890/crescimento-5g-brasil-depende-regulacao-normas.html
# getting page https://www.tudocelular.com/mercado/noticias/n138802/america-latina-atraso-leilao-5g-presidente-qualcomm.html
# getting page https://www.tudocelular.com/mercado/noticias/n137333/iphone-xi-tem-design-reforcado-em-vazamento.html
# getting page https://www.tudocelular.com/mercado/noticias/n140396/brasil-para-tras-pelo-menos-25-operadoras-5g-2019.html
# getting page https://www.tudocelular.com/mercado/noticias/n138802/america-latina-atraso-leilao-5g-presidente-qualcomm.html
# getting page https://www.tudocelular.com/mercado/noticias/n137333/iphone-xi-tem-design-reforcado-em-vazamento.html
# getting page https://www.tudocelular.com/mercado/noticias/n140396/brasil-para-tras-pelo-menos-25-operadoras-5g-2019.html
# ...

# %% [markdown]
# Quantidade final de arquivos baixados.

# %%
print(len(os.listdir('data/corpora/telefonia')))
# Out:
# 143

# %% [markdown]
# ### Saúde

# %% [markdown]
# Baixar no máximo 600 arquivos, se possível.

# %%
crawler.Crawler(
    'data/corpora/saude', 
    600, 
    'https://www1.folha.uol.com.br/equilibrioesaude/', 
    '"(https://www1\.folha\.uol\.com\.br/equilibrioesaude/\d+.*?)"'
).crawl()
# Out:
# getting page https://www1.folha.uol.com.br/equilibrioesaude/
# getting page https://www1.folha.uol.com.br/equilibrioesaude/2019/03/gemeas-que-nasceram-unidas-pela-cabeca-voltam-para-sua-casa-no-ceara.shtml
# getting page https://www1.folha.uol.com.br/equilibrioesaude/2019/03/para-evitar-promocao-do-aborto-brasil-critica-mencao-a-saude-reprodutiva-da-mulher-em-documento-da-onu.shtml
# getting page https://www1.folha.uol.com.br/equilibrioesaude/2019/04/orelhas-gigantes-em-sp-chamam-atencao-para-surdez-e-preconceito.shtml
# getting page https://www1.folha.uol.com.br/equilibrioesaude/2019/04/gloss-labial-dos-anos-90-volta-a-brilhar-em-2019.shtml
# getting page https://www1.folha.uol.com.br/equilibrioesaude/2019/04/novo-codigo-de-etica-medico-abre-brecha-para-consultas-a-distancia.shtml
# getting page https://www1.folha.uol.com.br/equilibrioesaude/2019/04/por-que-ficamos-desconfortaveis-quando-as-pessoas-se-aproximam-demais.shtml
# ...

# %% [markdown]
# Quantidade final de arquivos baixados.

# %%
print(len(os.listdir('data/corpora/saude')))
# Out:
# 212
